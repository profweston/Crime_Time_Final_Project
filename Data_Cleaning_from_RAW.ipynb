# %%
# Add dependencies
import pandas as pd
import numpy as np
import datetime as dt

# Files to load
file_to_load = "Crimes_RAW.csv"

# Read the CSV into a DataFrame
raw_crime_df = pd.read_csv(file_to_load)
raw_crime_df.head()
# Out:
#          ID Case Number                    Date                  Block  IUCR  \
# 0  10224738    HY411648  09/05/2015 01:30:00 PM        043XX S WOOD ST  0486
# 1  10224739    HY411615  09/04/2015 11:30:00 AM    008XX N CENTRAL AVE  0870
# 2  11646166    JC213529  09/01/2018 12:01:00 AM  082XX S INGLESIDE AVE  0810
# 3  10224740    HY411595  09/05/2015 12:45:00 PM      035XX W BARRY AVE  2023
# 4  10224741    HY411610  09/05/2015 01:00:00 PM    0000X N LARAMIE AVE  0560
#
#   Primary Type              Description Location Description  Arrest  \
# 0      BATTERY  DOMESTIC BATTERY SIMPLE            RESIDENCE   False
# 1        THEFT           POCKET-PICKING              CTA BUS   False
# 2        THEFT                OVER $500            RESIDENCE   False
# 3    NARCOTICS    POSS: HEROIN(BRN/TAN)             SIDEWALK    True
# 4      ASSAULT                   SIMPLE            APARTMENT   False
#
#    Domestic  ...  Ward  Community Area  FBI Code  X Coordinate Y Coordinate  \
# ...

# %%
# Drop Case Number, Block, IUCR, Description, Beat, Community Area, FBI Code, X & Y Coordinate, Updated On and Location.
raw_crime_df.drop(raw_crime_df.columns[[1, 3, 4, 6, 10, 12, 13, 14, 15, 16, 18, 21]], axis=1, inplace=True)
raw_crime_df.head()
# Out:
#          ID                    Date Primary Type Location Description  Arrest  \
# 0  10224738  09/05/2015 01:30:00 PM      BATTERY            RESIDENCE   False
# 1  10224739  09/04/2015 11:30:00 AM        THEFT              CTA BUS   False
# 2  11646166  09/01/2018 12:01:00 AM        THEFT            RESIDENCE   False
# 3  10224740  09/05/2015 12:45:00 PM    NARCOTICS             SIDEWALK    True
# 4  10224741  09/05/2015 01:00:00 PM      ASSAULT            APARTMENT   False
#
#    Domestic  District  Year   Latitude  Longitude
# 0      True       9.0  2015  41.815117 -87.670000
# 1     False      15.0  2015  41.895080 -87.765400
# 2      True       6.0  2018        NaN        NaN
# 3     False      14.0  2015  41.937406 -87.716650
# 4      True      15.0  2015  41.881903 -87.755121

# %%
# Remove NaN values
raw_crime_df.replace('NaN', np.NaN)
raw_crime_df = raw_crime_df.dropna()
raw_crime_df.head()
# Out:
#          ID                    Date Primary Type Location Description  Arrest  \
# 0  10224738  09/05/2015 01:30:00 PM      BATTERY            RESIDENCE   False
# 1  10224739  09/04/2015 11:30:00 AM        THEFT              CTA BUS   False
# 3  10224740  09/05/2015 12:45:00 PM    NARCOTICS             SIDEWALK    True
# 4  10224741  09/05/2015 01:00:00 PM      ASSAULT            APARTMENT   False
# 5  10224742  09/05/2015 10:55:00 AM     BURGLARY            RESIDENCE   False
#
#    Domestic  District  Year   Latitude  Longitude
# 0      True       9.0  2015  41.815117 -87.670000
# 1     False      15.0  2015  41.895080 -87.765400
# 3     False      14.0  2015  41.937406 -87.716650
# 4      True      15.0  2015  41.881903 -87.755121
# 5     False       6.0  2015  41.744379 -87.658431

# %%
# Split date column into Dates & Time
raw_crime_df["Dates"]=pd.to_datetime(raw_crime_df["Date"]).dt.date
raw_crime_df["Time"]=pd.to_datetime(raw_crime_df["Date"]).dt.time
raw_crime_df.head()
# Out:
#          ID                    Date Primary Type Location Description  Arrest  \
# 0  10224738  09/05/2015 01:30:00 PM      BATTERY            RESIDENCE   False
# 1  10224739  09/04/2015 11:30:00 AM        THEFT              CTA BUS   False
# 3  10224740  09/05/2015 12:45:00 PM    NARCOTICS             SIDEWALK    True
# 4  10224741  09/05/2015 01:00:00 PM      ASSAULT            APARTMENT   False
# 5  10224742  09/05/2015 10:55:00 AM     BURGLARY            RESIDENCE   False
#
#    Domestic  District  Year   Latitude  Longitude       Dates      Time
# 0      True       9.0  2015  41.815117 -87.670000  2015-09-05  13:30:00
# 1     False      15.0  2015  41.895080 -87.765400  2015-09-04  11:30:00
# 3     False      14.0  2015  41.937406 -87.716650  2015-09-05  12:45:00
# 4      True      15.0  2015  41.881903 -87.755121  2015-09-05  13:00:00
# 5     False       6.0  2015  41.744379 -87.658431  2015-09-05  10:55:00

# %%
# Remove the Date column
raw_crime_df.drop(raw_crime_df.columns[[1]], axis=1, inplace=True)
raw_crime_df.head()
# Out:
#          ID Primary Type Location Description  Arrest  Domestic  District  \
# 0  10224738      BATTERY            RESIDENCE   False      True       9.0
# 1  10224739        THEFT              CTA BUS   False     False      15.0
# 3  10224740    NARCOTICS             SIDEWALK    True     False      14.0
# 4  10224741      ASSAULT            APARTMENT   False      True      15.0
# 5  10224742     BURGLARY            RESIDENCE   False     False       6.0
#
#    Year   Latitude  Longitude       Dates      Time
# 0  2015  41.815117 -87.670000  2015-09-05  13:30:00
# 1  2015  41.895080 -87.765400  2015-09-04  11:30:00
# 3  2015  41.937406 -87.716650  2015-09-05  12:45:00
# 4  2015  41.881903 -87.755121  2015-09-05  13:00:00
# 5  2015  41.744379 -87.658431  2015-09-05  10:55:00

# %%
# Determine datatypes
raw_crime_df.dtypes
# Out:
# ID                        int64
# Primary Type             object
# Location Description     object
# Arrest                     bool
# Domestic                   bool
# District                float64
# Year                      int64
# Latitude                float64
# Longitude               float64
# Dates                    object
# Time                     object
# dtype: object

# %%
# Drop dates from before 2015
raw_crime_df['Dates'] = pd.to_datetime(raw_crime_df['Dates'])
filtered_crime_df = raw_crime_df[~(raw_crime_df['Dates'] < '2015-01-01')]
filtered_crime_df.head()
# Out:
#          ID Primary Type Location Description  Arrest  Domestic  District  \
# 0  10224738      BATTERY            RESIDENCE   False      True       9.0
# 1  10224739        THEFT              CTA BUS   False     False      15.0
# 3  10224740    NARCOTICS             SIDEWALK    True     False      14.0
# 4  10224741      ASSAULT            APARTMENT   False      True      15.0
# 5  10224742     BURGLARY            RESIDENCE   False     False       6.0
#
#    Year   Latitude  Longitude      Dates      Time
# 0  2015  41.815117 -87.670000 2015-09-05  13:30:00
# 1  2015  41.895080 -87.765400 2015-09-04  11:30:00
# 3  2015  41.937406 -87.716650 2015-09-05  12:45:00
# 4  2015  41.881903 -87.755121 2015-09-05  13:00:00
# 5  2015  41.744379 -87.658431 2015-09-05  10:55:00

# %%
# export the clean dataset
filtered_crime_df.to_csv('clean_crimewk2.csv')
